# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data = pd.read_csv("/content/drive/My Drive/Public Storage/data.csv")
data.head()
# Out:
#         Market Owner/Operator, Franchise                   ADDRESS  \
# 0  Albuquerque       Extra Space Storage       1522 Pacheco Street
# 1  Albuquerque       Extra Space Storage  1909 Golf Course Road SE
# 2  Albuquerque       Extra Space Storage      3300 Calle Cuervo NW
# 3  Albuquerque       Extra Space Storage   9831 Montgomery Blvd NE
# 4  Albuquerque       Extra Space Storage  9221 Eagle Ranch Road NW
#
#            CTY  ST    Zip     Area    Year
# 0     Santa Fe  NM  87505  73934.0  2000.0
# 1   Rio Rancho  NM  87124  72836.0  2000.0
# 2  Albuquerque  NM  87114  80889.0  1998.0
# 3  Albuquerque  NM  87111  62697.0  1997.0
# 4  Albuquerque  NM  87114  60821.0  1998.0

# %%
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 1.0 MB 27.0 MB/s
# ...
#      |████████████████████████████████| 16.7 MB 59.0 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 45.1 MB/s
# ...

# %%
# !pip install pgeocode

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pgeocode
import geopandas as gpd
from shapely.geometry import Point
import plotly.graph_objects as go

nomi = pgeocode.Nominatim('us')
data['Zip'] = data['Zip'].astype('str')

data['Latitude'] = (nomi.query_postal_code(data['Zip'].tolist()).latitude)
data['Longitude'] = (nomi.query_postal_code(data['Zip'].tolist()).longitude)

fig = go.Figure(data=go.Scattergeo(
        lon = data['Longitude'],
        lat = data['Latitude'],
        mode = 'markers'
        ))

fig.update_layout(
        title = 'Distribution of public operators self storage facilities',
        geo_scope='usa',
    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
